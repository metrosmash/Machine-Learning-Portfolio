# %% [markdown]
# <a href="https://colab.research.google.com/github/metrosmash/Machine-Learning-Portfolio/blob/main/Emission_indabax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Emissions IndabaX Version1
#
# my goals for this noteboook is to perform a simple Eda on the dataset and train a simple linear Regression model
# then keep experimenting until i am at the top of the dataset
